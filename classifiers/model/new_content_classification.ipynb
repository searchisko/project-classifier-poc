# %%
# a demonstration of use of the logistic regression classifier 
# for content classification on doc2vec docs vectors
# where logit probabilities of the classified content against the given categories can be used as relevance rating
# towards the classified categories

# references:
# [1] https://deeplearning4j.org/word2vec.html
# [2] http://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# [3] http://scikit-learn.org/stable/modules/cross_validation.html

# author Michal Stefanik  mistefan  at  redhat dot com

import numpy as np
import pandas as pd
import random

from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold

# D2VWrapper is our implementation providing vectorization of the documents based on doc2vec
from doc2vec_wrapper import D2VWrapper

import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# target categories
product_list = ["amq", "eap", "webserver", "datagrid", "fuse", "brms", "bpmsuite", "devstudio", "cdk",
                "developertoolset", "rhel", "softwarecollections", "mobileplatform", "openshift"]

# %%
# initialize d2v_wrapper providing as well metadata about the models state
d2v_wrapper = D2VWrapper(content_categories=product_list,
                         vector_length=500)
# EITHER initialize the vocab of documents and minimize the distances of embeddings in training phase
# d2v_wrapper.init_model_vocab(content_basepath="../../data/content/playground/auto/nostem",
#                              basepath_suffix="_content.csv", drop_short_docs=10)
# d2v_wrapper.train_model(shuffle=True, epochs=1 if TEST_MODE else 20)
# d2v_wrapper.infer_content_vectors()

# OR load initialized and trained wrapper if available
d2v_wrapper.load_persisted_wrapper("trained_models/wrapper/header_incl/10epoch_train_stem_not_removed_header")
# Out:
# 2017-04-26 14:29:35,096 : INFO : Loading serialized wrapper model from: trained_models/wrapper/header_incl/10epoch_train_stem_not_removed_header
# 2017-04-26 14:29:35,097 : INFO : Loading all_base_vocab_docs objects
# 2017-04-26 14:29:43,460 : INFO : Initialized 43478 headers of 43478 for vectorization
# 2017-04-26 14:29:43,461 : INFO : Loading all_base_vocab_docs vectors
# 2017-04-26 14:30:21,734 : INFO : Loading trained Doc2Vec model
# 2017-04-26 14:30:21,735 : INFO : loading Doc2Vec object from trained_models/wrapper/header_incl/10epoch_train_stem_not_removed_headerdoc2vec.mod
# 2017-04-26 14:30:21,998 : INFO : loading docvecs recursively from trained_models/wrapper/header_incl/10epoch_train_stem_not_removed_headerdoc2vec.mod.docvecs.* with mmap=None
# 2017-04-26 14:30:21,999 : INFO : loading doctag_syn0 from trained_models/wrapper/header_incl/10epoch_train_stem_not_removed_headerdoc2vec.mod.docvecs.doctag_syn0.npy with mmap=None
# 2017-04-26 14:30:22,170 : INFO : loading syn1neg from trained_models/wrapper/header_incl/10epoch_train_stem_not_removed_headerdoc2vec.mod.syn1neg.npy with mmap=None
# 2017-04-26 14:30:22,297 : INFO : loading syn0 from trained_models/wrapper/header_incl/10epoch_train_stem_not_removed_headerdoc2vec.mod.syn0.npy with mmap=None
# 2017-04-26 14:30:22,423 : INFO : setting ignored attribute syn0norm to None
# 2017-04-26 14:30:22,424 : INFO : setting ignored attribute cum_table to None

# %%
from common import parsing_utils as parsing

new_content_basepath = "/home/michal/Documents/Projects/ml/project-classifier-poc/project-classifier-poc/data/content/books_test/"
new_content_df = parsing.get_content_as_dataframe(new_content_basepath, ".csv", ["developers_redhat"])
new_content = parsing.select_training_content(new_content_df, sent_split=False)
new_content_headers = parsing.select_headers(new_content_df)
new_content_docs = parsing.tagged_docs_from_content(new_content, new_content_headers, pd.Series([None]*len(new_content)))
# Out:
# 2017-04-26 14:30:22,501 : INFO : Initializing 85 CategorizedDocuments

# %%
train_content = d2v_wrapper.infer_vocab_content_vectors()
train_content_vectors = train_content.iloc[:, :-1]
train_content_targets = train_content.iloc[:, -1]
# Out:
# 2017-04-26 14:30:22,515 : INFO : Returning already inferred doc vectors of 43478 all_base_vocab_docs

# %%
from sklearn.linear_model import LogisticRegression
# classifier training
logging.info("Fitting classifier")

log_reg_classifier = LogisticRegression(C=0.3, solver="sag", multi_class='ovr', n_jobs=8, max_iter=1000)
log_reg_classifier.fit(train_content_vectors, train_content_targets)
# Out:
# 2017-04-26 14:30:22,667 : INFO : Fitting classifier
# LogisticRegression(C=0.3, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=1000, multi_class='ovr', n_jobs=8,
#           penalty='l2', random_state=None, solver='sag', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
# classifier testing
logging.info("Predicting")
test_content_vectors = d2v_wrapper.infer_content_vectors(new_content_docs)
top_target_categories = log_reg_classifier.predict(test_content_vectors)
# Out:
# 2017-04-26 14:34:48,362 : INFO : Predicting
# 2017-04-26 14:34:48,363 : INFO : Initialized 85 headers of 85 for vectorization
# 2017-04-26 14:34:48,363 : INFO : Inferring vectors of 85 documents
# 2017-04-26 14:34:48,511 : INFO : Inferring vectors of 85 headers

# %%
new_content_df.keys()
# Out:
# Index([u'project', u'source', u'sys_content_plaintext', u'sys_description',
#        u'sys_title', u'sys_url_view', u'target'],
#       dtype='object')

# %%
# evaluation:
# logits
logging.info("Probs collection")
class_probs = log_reg_classifier.predict_proba(test_content_vectors)
class_ordered = list(log_reg_classifier.classes_)

class_actual_index = pd.Series(top_target_categories).apply(lambda cat_label: class_ordered.index(cat_label))
actual_prob = class_probs[np.arange(len(class_actual_index)),(class_actual_index)]

probs_matrix = pd.DataFrame(data=class_probs, columns=log_reg_classifier.classes_)
# probs_matrix["url"] = new_content_df["sys_url_view"]
top_five_cats = probs_matrix.apply(lambda row: row.nlargest(n=5), axis=1).columns
# Out:
# 2017-04-26 14:34:48,622 : INFO : Probs collection

# %%
probs_matrix.head(10)
# Out:
#         amq  bpmsuite      brms       cdk  datagrid  developertoolset  \
# 0  0.006989  0.000610  0.072619  0.008377  0.014659          0.000340
# 1  0.019781  0.006800  0.003922  0.000301  0.007276          0.000226
# 2  0.001071  0.004909  0.007066  0.000355  0.000389          0.000039
# 3  0.002680  0.034730  0.041035  0.000908  0.033139          0.000192
# 4  0.000472  0.001951  0.011906  0.000452  0.007861          0.000141
# 5  0.073711  0.013567  0.002593  0.000313  0.002283          0.000210
# 6  0.002207  0.001530  0.017849  0.000152  0.002154          0.000047
# 7  0.050461  0.006597  0.003294  0.001256  0.012030          0.000091
# 8  0.020994  0.004180  0.004101  0.000243  0.003530          0.000347
# 9  0.001926  0.004413  0.006540  0.000713  0.000040          0.000671
#
#    devstudio       eap      fuse  mobileplatform  openshift      rhel  \
# 0   0.040166  0.617561  0.077218        0.000162   0.005559  0.001161
# 1   0.010787  0.864492  0.047458        0.001210   0.000148  0.000793
# 2   0.478675  0.503412  0.000443        0.000400   0.000313  0.000124
# 3   0.014100  0.456726  0.380827        0.000285   0.000251  0.002124
# 4   0.036011  0.562413  0.096494        0.000408   0.000353  0.000011
# 5   0.171163  0.578954  0.086730        0.002615   0.003903  0.053562
# 6   0.002454  0.955179  0.001635        0.000562   0.000055  0.001953
# 7   0.011606  0.167315  0.008731        0.000544   0.000589  0.736043
# 8   0.012495  0.534061  0.363802        0.002091   0.001120  0.039482
# 9   0.029472  0.800179  0.018838        0.000136   0.029150  0.025805
#
#    softwarecollections  webserver
# 0             0.000236   0.154343
# 1             0.000071   0.036736
# 2             0.000030   0.002774
# 3             0.000179   0.032825
# 4             0.000030   0.281497
# 5             0.000155   0.010243
# 6             0.000040   0.014184
# 7             0.000102   0.001340
# 8             0.000100   0.013456
# 9             0.000616   0.081503

# %%
pd.set_option('max_colwidth', 400)

probs_matrix["url"] = new_content_df["sys_url_view"]

display_df = probs_matrix[list(top_five_cats)+["url"]]
display_df["header"] = new_content_df["sys_title"]

display_df = display_df[["header", "url"] + list(display_df.columns[:-2])]
# non_nan_mask
# cols = df.columns
# bt = df.apply(lambda x: x > 0)
# bt.apply(lambda x: list(cols[x.values]), axis=1)
# Out:
# /usr/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
display_df
# Out:
#                                                                                                header  \
# 0   beginning pojos lightweight java web development plain old java objects spring hibernate tapestry
# 1                                                                            jboss performance tuning
# 2                                                                        jboss tools developers guide
# 3                                                                            restful java jax edition
# 4                                                                       practical jboss seam projects
# 5                                                                     information systems development
# 6                                                                     jboss deployment administration
# 7                                                      distributed applications interoperable systems
# 8                                                           meaningful internet systems otm workshops
# 9                                                                                    expanding choice
# 10                                                                               enterprise javabeans
# 11                                                           beginning jboss seam novice professional
# 12                                                                               jboss official guide
# 13                                                                    jboss portal server development
# 14                                                              service oriented architecture dummies
# 15                                                                         jboss work practical guide
# 16                                                                                              jboss
# 17                                                              energy efficient computing networking
# 18                                                                   jboss administration development
# 19                                                                                      jee und jboss
# 20                                                                    beginning jsf  apis jboss  seam
# 21                                                        jmx managing jee java management extensions
# 22                                                                               java message service
# 23                                                      rule representation interchange reasoning web
# 24                                                    agile java development spring hibernate eclipse
# 25                                                                               beginning jboss seam
# 26                                                                       jboss weld cdi java platform
# 27                                                                           jboss esb beginner guide
# 28                                                           pro eclipse jst plug ins jee development
# 29                                                      jboss configuration deployment administration
# ..                                                                                                ...
# 55                                                  jboss action configuring jboss application server
# 56                                                           seam framework experience evolution java
# 57                                                         enterprise javabeans mit eclipse und jboss
# 58                                                                                      jboss einsatz
# 59                                                                                    jboss richfaces
# 60                                                                       jboss weld cdi java platform
# 61                                                                                  jboss development
# 62         embracing jboss seam examination streamlined unified java enterprise application framework
# 63                                                                                beginning hibernate
# 64                                                        hibernate recipes problem solution approach
# 65                                                                       enterprise javabeans edition
# 26                                                                         http://books.google.com/books/about/Jboss_Weld_CDI_for_Java_Platform.html?hl=&id=Wh36a6zntX0C
# 27                                                                               http://books.google.com/books/about/Jboss_Esb_Beginner_s_Guide.html?hl=&id=xjCLHCeZmxYC
# 28                                                                                                                                   http://www.apress.com/9781590594933
# 29                                                                   https://www.packtpub.com/networking-and-servers/jboss-7-configuration-deployment-and-administration
# ..                                                                                                                                                                   ...
# 55                                                                          http://www.pearson.ch/Informatik/Manning/1471/9781933988023/JBoss-in-Action-Configuring.aspx
# 56                                                 http://www.pearsonhighered.com/educator/product/Seam-Framework-Experience-the-Evolution-of-Java-EE/9780137129393.page
# 57                                                                 http://books.google.com/books/about/Enterprise_JavaBeans_3_0_mit_Eclipse_und.html?hl=&id=BezfXaxWwt4C
# 58                                                                                http://books.google.com/books?id=uMpF7IJNmH4C&dq=isbn:9783446415744&hl=&source=gbs_api
# 59                                                                                                   https://www.packtpub.com/application-development/jboss-richfaces-33
# 60                                                                                         https://www.packtpub.com/application-development/jboss-weld-cdi-java-platform
# 61                                                                                                   https://www.packtpub.com/networking-and-servers/jboss-5-development
# 62  http://www.amazon.com/Embracing-JBoss-Seam-Examination-streamlined/dp/3639252772/ref=sr_1_1/191-6264234-7342033?ie=UTF8&qid=1415737250&sr=8-1&keywords=9783639252774
# 63                                                                                                                                   http://www.apress.com/9781430228509
# 64                                                                                                                                   http://www.apress.com/9781430227960
# 65                                                                                                                      http://shop.oreilly.com/product/9780596158033.do
# 66                                                                                            https://www.packtpub.com/networking-and-servers/jboss-5-performance-tuning
# 67                                http://books.google.com.sg/books?id=g3TCFczl0IwC&printsec=frontcover&dq=isbn:9781430234494&hl=&cd=1&source=gbs_api#v=onepage&q&f=false
# 68                                                                                  https://www.packtpub.com/application-development/drools-developer%E2%80%99s-cookbook
# 69                                                                                    https://www.packtpub.com/networking-and-servers/jboss-esb-beginner%E2%80%99s-guide
# 70                                                                             https://www.packtpub.com/big-data-and-business-intelligence/infinispan-data-grid-platform
# 71                                                                          https://www.packtpub.com/application-development/hornetq-messaging-developer%E2%80%99s-guide
# 72                                                                                                 https://www.packtpub.com/networking-and-servers/jbpm5-developer-guide
# 73                                                                                             https://www.packtpub.com/application-development/hibernate-search-example
# 74                                                                                       https://www.packtpub.com/application-development/instant-drools-starter-instant
# 75                                                                                             https://www.packtpub.com/application-development/arquillian-testing-guide
# 76                                                                      https://www.packtpub.com/application-development/drools-jboss-rules-5x-developer%E2%80%99s-guide
# 77                                                                                     http://books.google.com/books/about/Spring_And_Hibernate.html?hl=&id=NfNbbhBRcOkC
# 78                                                                                                                         http://www.springer.com/gp/book/9781430257943
# 79                                                                                                  https://www.packtpub.com/application-development/jboss-7-development
# 80                                                                                                                                         http://www.manning.com/ibsen/
# 81                                                                                                                                        http://www.manning.com/bauer3/
# 82                                                                                  https://books.google.com/books?id=zGEYAgAAQBAJ&dq=isbn:1449361455&hl=&source=gbs_api
# 83                                                                                         https://www.packtpub.com/application-development/jboss-eap6-high-availability
# 20  0.091391        0.000179   0.000307  0.000415   0.144147
# 21  0.308960        0.002217   0.000026  0.008238   0.005172
# 22  0.608818        0.011432   0.004201  0.022641   0.000334
# 23  0.039266        0.029048   0.007774  0.004802   0.078989
# 24  0.694357        0.000574   0.016786  0.048941   0.003640
# 25  0.002708        0.007645   0.032370  0.009775   0.101914
# 26  0.523209        0.000874   0.000722  0.000368   0.016347
# 27  0.417759        0.000153   0.000217  0.002502   0.022337
# 28  0.020283        0.008432   0.004283  0.211624   0.041433
# 29  0.038241        0.000504   0.000036  0.001939   0.040676
# ..       ...             ...        ...       ...        ...
# 55  0.186518        0.000112   0.001805  0.000326   0.055314
# 56  0.260749        0.000527   0.001922  0.002513   0.018367
# 57  0.012767        0.001369   0.000152  0.000488   0.005189
# 58  0.022401        0.000032   0.000209  0.010913   0.021837
# 59  0.046712        0.003534   0.000156  0.000639   0.054129
# 60  0.018417        0.001179   0.000100  0.000018   0.036815
# 61  0.085065        0.002061   0.004175  0.002134   0.047782
# 62  0.003026        0.000253   0.000082  0.000725   0.014836
# 63  0.015070        0.004687   0.006893  0.003068   0.020867
# 64  0.072716        0.005651   0.025037  0.018245   0.136601
# 65  0.098987        0.000536   0.000076  0.022268   0.003352
# 66  0.201266        0.002167   0.000291  0.001782   0.070365
# 67  0.328399        0.072566   0.007362  0.069954   0.031602
# 68  0.070203        0.002014   0.145824  0.419905   0.000683
# 69  0.076896        0.002550   0.000572  0.142029   0.164965
# 70  0.030546        0.000512   0.011883  0.006340   0.049642
# 71  0.003303        0.000206   0.000277  0.000544   0.028451
# 72  0.006941        0.001345   0.143895  0.022994   0.010858
# 73  0.165141        0.005720   0.013506  0.026830   0.005604
# 74  0.041816        0.001278   0.348220  0.000264   0.000039
# 75  0.336501        0.001192   0.000753  0.004268   0.004803
# 76  0.044295        0.006339   0.048173  0.007787   0.008642
# 77  0.776027        0.000647   0.008286  0.004073   0.012289
# 78  0.007487        0.011860   0.089316  0.009805   0.010483
# 79  0.089651        0.000641   0.000481  0.001220   0.015287
# 80  0.380085        0.008493   0.000472  0.075561   0.084777
# 81  0.060763        0.014804   0.006134  0.000421   0.011446
# 82  0.019312        0.000065   0.000092  0.071115   0.132645
# 83  0.019555        0.000101   0.000022  0.018004   0.010957
# 84  0.028102        0.000381   0.000288  0.007436   0.002529
#
# [85 rows x 14 columns]

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s > 0.2
    return ['background-color: yellow' if v else '' for v in is_max]

# %%
display_df.style.apply(highlight_max, axis=1)
# Out:
#         <style  type="text/css" >
#
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row0_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row0_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row0_col8 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row1_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row1_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row1_col8 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row2_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row2_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row2_col7 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row2_col8 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row3_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row3_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row3_col8 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row3_col9 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row4_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row4_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row4_col8 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row4_col13 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row5_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row5_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row5_col8 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row6_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row6_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row6_col8 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row7_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row7_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row7_col12 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row8_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row8_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row8_col8 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row8_col9 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row9_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row9_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row9_col8 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row10_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row10_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row10_col8 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row11_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row11_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row11_col8 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row12_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row12_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row12_col8 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row13_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row13_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row13_col9 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row14_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row14_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row14_col8 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row14_col9 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8_2a7f_11e7_bff8_5cc5d4de66e2row15_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_4f7361f8
